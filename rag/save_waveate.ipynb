# %%
import weaviate
import requests, json
from weaviate.classes.config import Configure

client = weaviate.connect_to_local()

# %%
import weaviate.classes as wvc

collection = client.collections.create(
        name="medbooks",
        properties=[
            wvc.config.Property(name="path", data_type=wvc.config.DataType.TEXT),
            wvc.config.Property(name="chunk_id", data_type=wvc.config.DataType.INT),
            wvc.config.Property(name="text", data_type=wvc.config.DataType.TEXT),
        ],
        # no vectorizer_config => BYO vectors
    )
# Out:
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeError                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import weaviate.classes as wvc
# ----> 3 collection = client.collections.create(
#       4         name="medbooks",
#       5         properties=[
#       6             wvc.config.Property(name="path", data_type=wvc.config.DataType.TEXT),
#       7             wvc.config.Property(name="chunk_id", data_type=wvc.config.DataType.INT),
#       8             wvc.config.Property(name="text", data_type=wvc.config.DataType.TEXT),
#       9         ],
#      10         # no vectorizer_config => BYO vectors
#      11     )
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\collections\collections\executor.py:240, in _CollectionsExecutor.create(self, name, description, generative_config, inverted_index_config, multi_tenancy_config, properties, references, replication_config, reranker_config, sharding_config, vector_index_config, vectorizer_config, vector_config, data_model_properties, data_model_references, skip_argument_validation)
#     235 except ValidationError as e:
#     236     raise WeaviateInvalidInputError(
#     237         f"Invalid collection config create parameters: {e}"
#     238     ) from e
# --> 240 return self.__create(
#     241     config=config._to_dict(),
#     242     data_model_properties=data_model_properties,
#     243     data_model_references=data_model_references,
#     244     skip_argument_validation=skip_argument_validation,
#     245 )
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\collections\collections\executor.py:104, in _CollectionsExecutor.__create(self, config, data_model_properties, data_model_references, skip_argument_validation)
#      93 def __create(
#      94     self,
#      95     *,
#    (...)    102     Awaitable[CollectionAsync[Properties, References]],
#     103 ]:
# --> 104     result = self._connection.post(
#     105         path="/schema",
#     106         weaviate_object=config,
#     107         error_msg="Collection may not have been created properly.",
#     108         status_codes=_ExpectedStatusCodes(ok_in=200, error="Create collection"),
#     109     )
#     111     if isinstance(result, Awaitable):
#     113         async def execute_():
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:824, in _ConnectionBase.post(self, path, weaviate_object, params, error_msg, status_codes, is_gql_query)
#     815 def post(
#     816     self,
#     817     path: str,
#    (...)    822     is_gql_query: bool = False,
#     823 ) -> executor.Result[Response]:
# --> 824     return self._send(
#     825         "POST",
#     826         url=self.url + self._api_version_path + path,
#     827         weaviate_object=weaviate_object,
#     828         params=params,
#     829         error_msg=error_msg,
#     830         status_codes=status_codes,
#     831         is_gql_query=is_gql_query,
#     832     )
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:718, in _ConnectionBase._send(self, method, url, error_msg, status_codes, is_gql_query, weaviate_object, params, check_is_connected)
#     715 def exc(e: Exception) -> None:
#     716     self.__handle_exceptions(e, error_msg)
# --> 718 return executor.execute(
#     719     response_callback=resp,
#     720     exception_callback=exc,
#     721     method=self._client.send,
#     722     request=request,
#     723 )
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\executor.py:99, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      97     return resp_call
#      98 except Exception as e:
# ---> 99     return cast(T, exception_callback(e))
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:716, in _ConnectionBase._send.<locals>.exc(e)
#     715 def exc(e: Exception) -> None:
# --> 716     self.__handle_exceptions(e, error_msg)
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:672, in _ConnectionBase.__handle_exceptions(self, e, error_msg)
#     670 if isinstance(e, ReadTimeout):
#     671     raise WeaviateTimeoutError(error_msg) from e
# --> 672 raise e
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\executor.py:95, in execute(method, response_callback, exception_callback, *args, **kwargs)
#      92             return cast(T, exception_callback(e))
#      94     return _execute()
# ---> 95 resp_call = response_callback(call)
#      96 assert not isinstance(resp_call, Awaitable)
#      97 return resp_call
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:713, in _ConnectionBase._send.<locals>.resp(res)
#     712 def resp(res: Response) -> Response:
# --> 713     return self.__handle_response(res, error_msg, status_codes)
#
# File c:\Users\maths\prof\waveate_verba\.venv\Lib\site-packages\weaviate\connect\v4.py:683, in _ConnectionBase.__handle_response(self, response, error_msg, status_codes)
#     681     raise InsufficientPermissionsError(response)
#     682 if status_codes is not None and response.status_code not in status_codes.ok:
# --> 683     raise UnexpectedStatusCodeError(error_msg, response)
#     684 return response
#
# UnexpectedStatusCodeError: Collection may not have been created properly.! Unexpected status code: 422, with response body: {'error': [{'message': 'class name Medbooks already exists'}]}.

# %%
import os, glob, uuid, json, time
from typing import List
import requests
import weaviate
from weaviate.util import generate_uuid5
from tqdm import tqdm

OLLAMA_URL = "http://localhost:11434/api/embeddings"
OLLAMA_MODEL = "hf.co/mradermacher/MedEmbed-large-v0.1-GGUF:Q4_K_M"  # change to 'nomic-embed-text' if needed
DATA_DIR = "./med_txt"  # folder that contains your 10 .txt files
CHUNK_SIZE = 1200       # chars
CHUNK_OVERLAP = 200

def chunk_text(text: str, size: int, overlap: int) -> List[str]:
    chunks = []
    start = 0
    n = len(text)
    while start < n:
        end = min(start + size, n)
        chunks.append(text[start:end])
        if end == n: break
        start = end - overlap
        if start < 0: start = 0
    return chunks

def embed(text: str) -> List[float]:
    # Ollama embeddings API uses 'prompt'
    payload = {"model": OLLAMA_MODEL, "prompt": text}
    r = requests.post(OLLAMA_URL, json=payload, timeout=120)
    r.raise_for_status()
    vec = r.json().get("embedding") or r.json().get("data", [{}])[0].get("embedding")
    if not vec:
        raise RuntimeError(f"Missing 'embedding' in Ollama response: {r.text[:200]}")
    return vec

# %%
coll = client.collections.get("medbooks")

files = sorted(glob.glob(os.path.join(DATA_DIR, "*.txt")))
if not files:
    raise SystemExit(f"No .txt files found under {DATA_DIR}")

to_insert = []   # accumulate for insert_many
vectors = []     # parallel list of vectors

for path in files:
    with open(path, "r", encoding="utf-8", errors="ignore") as f:
        text = f.read()

    chunks = chunk_text(text, CHUNK_SIZE, CHUNK_OVERLAP)
    for i, chunk in enumerate(chunks):
        # small guard against empty/whitespace
        c = chunk.strip()
        if not c:
            continue

        vec = embed(c)
        obj = {
            "path": os.path.basename(path),
            "chunk_id": i,
            "text": c,
        }
        to_insert.append(obj)
        vectors.append(vec)

# Efficient upsert: insert_many supports passing parallel vectors
# For very large corpora prefer collection.batch (dynamic batching). :contentReference[oaicite:5]{index=5}
res = coll.data.insert_many(objects=to_insert, vectors=vectors)
if res.has_errors:
    print("Some insert errors:", res.errors)
else:
    print(f"Inserted {len(to_insert)} chunks into 'med-books'")

# %%
import weaviate, requests

OLLAMA_URL = "http://localhost:11434/api/embeddings"
OLLAMA_MODEL = "hf.co/mradermacher/MedEmbed-large-v0.1-GGUF:Q4_K_M"

def embed(q: str):
    r = requests.post(OLLAMA_URL, json={"model": OLLAMA_MODEL, "prompt": q}, timeout=60)
    r.raise_for_status()
    return r.json()["embedding"]

client = weaviate.connect_to_local()
try:
    coll = client.collections.get("medbooks")
    qv = embed("pathophysiology")
    # near_vector search; request back selected properties
    out = coll.query.near_vector(
        near_vector=qv,
        limit=5,
        return_metadata=wvc.query.MetadataQuery(distance=True),
        return_properties=["path", "chunk_id", "text"]
    )
    for o in out.objects:
        print(f"[{o.properties['path']}#{o.properties['chunk_id']}] dist={o.metadata.distance:.4f}")
        print(o.properties["text"][:300], "\n---")
finally:
    client.close()

# %%
client = weaviate.connect_to_local()

try:
    coll = client.collections.get("medbooks")

    res = coll.query.fetch_objects(limit=5, return_properties=["path", "chunk_id", "text"])

    for o in res.objects:
        print(f"{o.properties['path']}#{o.properties['chunk_id']}")
        print(o.properties["text"][:200], "...\n---")
finally:
    client.close()
